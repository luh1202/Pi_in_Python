# %% [markdown]
# # Python Implementations of Pi Algorithms
# # Collected and Organised by Yu Geng
# # Last Update: 2017-09-19
# Symbol $\pi$ does not render in the correct font size on GitHub.

# %% [markdown]
# ### Chudnovsky Algorithm
# ### From Wikipedia
# ### https://en.wikipedia.org/wiki/Chudnovsky_algorithm

# %%
from decimal import Decimal as Dec, getcontext as gc

def PI(maxK=70, prec=1008, disp=1007):
    # parameter defaults chosen to gain
    # 1000+ digits within a few seconds
    gc().prec = prec
    K, M, L, X, S = 6, 1, 13591409, 1, 13591409 
    for k in range(1, maxK+1):
        M = (K**3 - (K<<4)) * M / k**3 
        L += 545140134
        X *= -262537412640768000
        S += Dec(M * L) / X
        K += 12
    pi = 426880 * Dec(10005).sqrt() / S
    pi = Dec(str(pi)[:disp]) # drop few digits of precision for accuracy
    print("PI(maxK=%d iterations, gc().prec=%d, disp=%d digits) =\n%s" \
          % (maxK, prec, disp, pi))
    return pi

# %%
# %%time
# everytime the function calls, it produces repeated output
Pi = PI()  # do not use %timeit
# Out:
# PI(maxK=70 iterations, gc().prec=1008, disp=1007 digits) =
# 3....
# CPU times: user 35.7 ms, sys: 694 µs, total: 36.4 ms
# Wall time: 36.2 ms

# %%
# %%time

Pi = PI(317,4501,4500)
# Out:
# PI(maxK=317 iterations, gc().prec=4501, disp=4500 digits) =
# 3....
# CPU times: user 2.15 s, sys: 5.56 ms, total: 2.15 s
# Wall time: 2.19 s

# %%
# %%time

Pi = PI(353,5022,5020)
# Out:
# PI(maxK=353 iterations, gc().prec=5022, disp=5020 digits) =
# 3....
# CPU times: user 2.99 s, sys: 15.7 ms, total: 3.01 s
# Wall time: 3.13 s
